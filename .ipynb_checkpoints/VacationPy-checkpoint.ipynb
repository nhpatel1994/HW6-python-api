# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Study data files
weather_data_path = "output_data/cities.csv"


# Read the mouse data and the study results
weather_df = pd.read_csv(weather_data_path)

weather_df
# Out:
#      Unnamed: 0        City      Lat       Lng  Max Temp  Humidity  \
# 0             0     Rikitea -23.1203 -134.9692     75.70        76
# 1             1   Phang Nga   8.4509   98.5298     80.64        92
# 2             2     Atambua  -9.1061  124.8925     73.62        90
# 3             3        Chui -33.6971  -53.4616     61.36        54
# 4             4    Tasiilaq  65.6145  -37.6368     44.76        42
# ..          ...         ...      ...       ...       ...       ...
# 568         568        Bara  10.3744   10.7288    103.93        20
# 569         569     Itarema  -2.9248  -39.9167     82.85        76
# 570         570  Vyartsilya  62.1764   30.6930     37.60        96
# 571         571        Puro  12.4841  123.3827     81.16        82
# 572         572  Banda Aceh   5.5577   95.3222     82.42        79
#
#      Cloudiness  Wind Speed Country        Date
# 0            48       13.18      PF  1651331037
# 1            98        3.00      TH  1651331210
# 2            74        4.34      ID  1651331210
# 3            56        3.38      UY  1651331149
# 4            70       14.36      GL  1651331212
# ..          ...         ...     ...         ...
# 568          80        4.70      NG  1651331557
# 569          63       10.02      BR  1651331558
# 570         100        6.29      RU  1651331559
# 571          98        9.86      PH  1651331559
# 572         100        6.35      ID  1651331560
#
# [573 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
figure_layout = {
    'width': '800px',
    'height': '600px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout)

# %%
coordinates = weather_df[['Lat','Lng']]

humidity = weather_df["Humidity"]

# Create heat layer
heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity, dissipating=False, max_intensity=10, point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
hotel_df = weather_df.loc[(weather_df['Max Temp'] > 70) & (weather_df['Max Temp'] < 90)]

hotel_df.dropna()

hotel_df
# Out:
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 0             0         Rikitea -23.1203 -134.9692     75.70        76
# 1             1       Phang Nga   8.4509   98.5298     80.64        92
# 2             2         Atambua  -9.1061  124.8925     73.62        90
# 6             6  Saint-Philippe -21.3585   55.7679     80.19        79
# 12           12           Vaini -21.2000 -175.2000     75.36       100
# ..          ...             ...      ...       ...       ...       ...
# 566         566            Sola -13.8833  167.5500     81.77        72
# 567         567           Karak  31.1667   35.7500     71.87        40
# 569         569         Itarema  -2.9248  -39.9167     82.85        76
# 571         571            Puro  12.4841  123.3827     81.16        82
# 572         572      Banda Aceh   5.5577   95.3222     82.42        79
#
#      Cloudiness  Wind Speed Country        Date
# 0            48       13.18      PF  1651331037
# 1            98        3.00      TH  1651331210
# 2            74        4.34      ID  1651331210
# 6            45       11.18      RE  1651331078
# 12          100        6.91      TO  1651331216
# ..          ...         ...     ...         ...
# 566          60        3.98      VU  1651331556
# 567           0       25.01      JO  1651331557
# 569          63       10.02      BR  1651331558
# 571          98        9.86      PH  1651331559
# 572         100        6.35      ID  1651331560
#
# [225 rows x 10 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# set up additional columns to hold information

hotel_df['Hotel Name'] = ''

hotel_df.head()

#I'm not sure how to get the warning below to go away.
# Out:
# /var/folders/_y/tzd7c5gn6cd2j2f3dzv91_vh0000gn/T/ipykernel_33903/1187363465.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#     Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 0            0         Rikitea -23.1203 -134.9692     75.70        76
# 1            1       Phang Nga   8.4509   98.5298     80.64        92
# 2            2         Atambua  -9.1061  124.8925     73.62        90
# 6            6  Saint-Philippe -21.3585   55.7679     80.19        79
# 12          12           Vaini -21.2000 -175.2000     75.36       100
#
#     Cloudiness  Wind Speed Country        Date Hotel Name
# 0           48       13.18      PF  1651331037
# 1           98        3.00      TH  1651331210
# 2           74        4.34      ID  1651331210
# 6           45       11.18      RE  1651331078
# 12         100        6.91      TO  1651331216

# %%
hotel_df = good_cities_df

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
}

# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():

    # get location from df
    lat = row['Lat']
    lng = row['Lng']
    
    params['location'] = f'{lat},{lng}'

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {row['City']}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")

hotel_df
# Out:
# Retrieving Results for Index 0: Rikitea.
# Closest hotel is People ThankYou.
# ------------
# Retrieving Results for Index 1: Phang Nga.
# /Users/nikunjpatel/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest hotel is Sunimit Mansion.
# ------------
# Retrieving Results for Index 2: Atambua.
# Closest hotel is Kost Alfa Flat.
# ------------
# Retrieving Results for Index 6: Saint-Philippe.
# Closest hotel is Chambres d'hôte "La Trinité".
# ------------
# Retrieving Results for Index 12: Vaini.
# Closest hotel is Keleti Beach Resort.
# ------------
# Retrieving Results for Index 18: Puerto Ayora.
# Closest hotel is Finch Bay Galapagos Hotel.
# ------------
# Retrieving Results for Index 20: Chapadinha.
# Closest hotel is Chapadinhense Hotel.
# ------------
# Retrieving Results for Index 21: Meulaboh.
# Closest hotel is Kost Pria.
# ------------
# Retrieving Results for Index 25: Avarua.
# Closest hotel is Paradise Inn.
# ------------
# Retrieving Results for Index 28: Sumter.
# Closest hotel is Paradise Oaks RV Resort.
# ------------
# Retrieving Results for Index 34: Atuona.
# Closest hotel is Villa Enata.
# ------------
# Retrieving Results for Index 35: Ponta do Sol.
# Closest hotel is Hotel do Campo.
# ------------
# Retrieving Results for Index 41: Hong Kong.
# Closest hotel is Mini Hotel Central.
# ------------
# Retrieving Results for Index 42: Kumbo.
# Closest hotel is Western Inn Resort.
# ------------
# Retrieving Results for Index 43: Koregaon.
# Closest hotel is hotel nisarg lounge.
# ------------
# Retrieving Results for Index 45: Port-Gentil.
# Closest hotel is Fengshui Residence.
# ------------
# Retrieving Results for Index 46: Caravelas.
# Closest hotel is Pousada dos Navegantes.
# ------------
# Retrieving Results for Index 48: Arraial do Cabo.
# Closest hotel is Pousada Porto Praia.
# ------------
# Retrieving Results for Index 61: Bengkulu.
# Closest hotel is Grage Hotel Bengkulu.
# ------------
# Retrieving Results for Index 62: Cabo San Lucas.
# Closest hotel is Hotel Tesoro Los Cabos.
# ------------
# Retrieving Results for Index 63: Vanimo.
# Closest hotel is Vahmoneh Lodge Vanimo.
# ------------
# Retrieving Results for Index 64: Ouésso.
# Closest hotel is ABENIE Hotel.
# ------------
# Retrieving Results for Index 65: Yangi Marg`ilon.
# Closest hotel is Ikathouse.
# ------------
# Retrieving Results for Index 69: Sittwe.
# Closest hotel is Hotel Memory.
# ------------
# Retrieving Results for Index 72: Hilo.
# Closest hotel is Hilo Hawaiian Hotel.
# ------------
# Retrieving Results for Index 73: Tiznit Province.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 74: Lorengau.
# Closest hotel is Lorengau Harbourside Hotel.
# ------------
# Retrieving Results for Index 79: Touros.
# Closest hotel is INN NEW HORIZON.
# ------------
# Retrieving Results for Index 80: Grand Gaube.
# Closest hotel is Veranda Paul et Virginie Hotel & Spa.
# ------------
# Retrieving Results for Index 86: Waingapu.
# Closest hotel is Pondok Wisata Elim.
# ------------
# Retrieving Results for Index 90: Tual.
# Closest hotel is Grand Vilia Hotel.
# ------------
# Retrieving Results for Index 95: Casablanca.
# Closest hotel is فندق البيت المغربي كازبلانكا.
# ------------
# Retrieving Results for Index 96: Roebourne.
# Closest hotel is Latitude20 Roebourne Village.
# ------------
# Retrieving Results for Index 99: Bathsheba.
# Closest hotel is Atlantis Hotel.
# ------------
# Retrieving Results for Index 100: Tonantins.
# Closest hotel is Hotel Hortensias.
# ------------
# Retrieving Results for Index 102: Altea.
# Closest hotel is Albir Playa Hotel & Spa.
# ------------
# Retrieving Results for Index 106: Charters Towers.
# Closest hotel is Cattleman's Rest Motor Inn.
# ------------
# Retrieving Results for Index 112: Wilmington.
# Closest hotel is Hotel Ballast Wilmington, Tapestry Collection by Hilton.
# ------------
# Retrieving Results for Index 115: Hithadhoo.
# Closest hotel is Scoop Guest House.
# ------------
# Retrieving Results for Index 117: Talara.
# Closest hotel is Hostal Oro Negro.
# ------------
# Retrieving Results for Index 119: Iralaya.
# Closest hotel is Iglesia morava renovada.
# ------------
# Retrieving Results for Index 122: Uauá.
# Closest hotel is Hotel Uauá.
# ------------
# Retrieving Results for Index 124: Kerema.
# Closest hotel is Frena Lodge.
# ------------
# Retrieving Results for Index 125: Acapulco de Juárez.
# Closest hotel is HS Hotsson Smart Acapulco.
# ------------
# Retrieving Results for Index 126: Lagos.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 127: Porto-Novo.
# Closest hotel is Tour Eiffel Hotel Benin.
# ------------
# Retrieving Results for Index 131: Butaritari.
# Closest hotel is Isles Sunset Lodge.
# ------------
# Retrieving Results for Index 134: Fomboni.
# Closest hotel is Auberge les abou.
# ------------
# Retrieving Results for Index 135: Paluan.
# Closest hotel is Mom's Bed and Breakfast.
# ------------
# Retrieving Results for Index 136: Salinópolis.
# Closest hotel is Salinas Park Resort Maçarico AP101.
# ------------
# Retrieving Results for Index 140: Palauig.
# Closest hotel is Alperi Botique Resort.
# ------------
# Retrieving Results for Index 141: Oodweyne.
# Closest hotel is Eng Hiirey House.
# ------------
# Retrieving Results for Index 144: George Town.
# Closest hotel is Cititel Penang.
# ------------
# Retrieving Results for Index 145: Poya.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 146: Cumana.
# Closest hotel is Posada Acuarela Los Roques.
# ------------
# Retrieving Results for Index 151: Paripiranga.
# Closest hotel is Rancho N. Senhora De Fátima.
# ------------
# Retrieving Results for Index 155: Sunrise.
# Closest hotel is Holiday Inn Express & Suites Ft. Lauderdale-Plantation, an IHG Hotel.
# ------------
# Retrieving Results for Index 156: Lira.
# Closest hotel is ST Lira Hotel Limited.
# ------------
# Retrieving Results for Index 161: Kapaa.
# Closest hotel is Sheraton Kauai Coconut Beach Resort.
# ------------
# Retrieving Results for Index 162: Kalmunai.
# Closest hotel is VS Villa.
# ------------
# Retrieving Results for Index 163: Conceição do Araguaia.
# Closest hotel is Tarumã Tropical Hotel.
# ------------
# Retrieving Results for Index 164: Kavieng.
# Closest hotel is Nusa Island Retreat.
# ------------
# Retrieving Results for Index 168: Bambous Virieux.
# Closest hotel is Casa Tia Villa.
# ------------
# Retrieving Results for Index 171: Gambēla.
# Closest hotel is Solomon Debebe Hotel.
# ------------
# Retrieving Results for Index 173: São João da Barra.
# Closest hotel is Pousada Porto De Canoas.
# ------------
# Retrieving Results for Index 174: Labuhan.
# Closest hotel is DoubleFAG.
# ------------
# Retrieving Results for Index 175: Bonthe.
# Closest hotel is Bonthe Holiday Village.
# ------------
# Retrieving Results for Index 180: Maningrida.
# Closest hotel is Dhukurrdji Lodge.
# ------------
# Retrieving Results for Index 182: Baharly.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 184: Chiang Kham.
# Closest hotel is Rico Resort.
# ------------
# Retrieving Results for Index 186: Marakkanam.
# Closest hotel is Samvasa by the Sea.
# ------------
# Retrieving Results for Index 188: Kununurra.
# Closest hotel is Hotel Kununurra.
# ------------
# Retrieving Results for Index 189: Faanui.
# Closest hotel is Bora-Bora Pearl Beach Resort & Spa.
# ------------
# Retrieving Results for Index 191: Honiara.
# Closest hotel is Heritage Park Hotel.
# ------------
# Retrieving Results for Index 192: São Filipe.
# Closest hotel is Hotel Xaguate.
# ------------
# Retrieving Results for Index 193: Port Moresby.
# Closest hotel is Lamana Hotel (Port Moresby).
# ------------
# Retrieving Results for Index 200: Ambilobe.
# Closest hotel is Hôtel & Restaurant DIANA Ambilobe.
# ------------
# Retrieving Results for Index 204: Puri.
# Closest hotel is OYO 1577 Hotel Shree Hari Grand.
# ------------
# Retrieving Results for Index 210: Diego de Almagro.
# Closest hotel is hotel luna del desierto.
# ------------
# Retrieving Results for Index 212: Lázaro Cárdenas.
# Closest hotel is HOTEL QUINTA ANTIGUA.
# ------------
# Retrieving Results for Index 213: Abu Dhabi.
# Closest hotel is Beach Rotana.
# ------------
# Retrieving Results for Index 215: Cayenne.
# Closest hotel is Hôtel Le Dronmi.
# ------------
# Retrieving Results for Index 223: San Patricio.
# Closest hotel is Motel 6 Sinton, TX.
# ------------
# Retrieving Results for Index 224: Tautira.
# Closest hotel is Pension Oaoa.
# ------------
# Retrieving Results for Index 229: Beaufort.
# Closest hotel is The Gem Hotel Beaufort.
# ------------
# Retrieving Results for Index 232: Sokoni.
# Closest hotel is Ujamaa Beach Resort.
# ------------
# Retrieving Results for Index 242: Gweta.
# Closest hotel is Gweta Lodge.
# ------------
# Retrieving Results for Index 244: Basoko.
# Closest hotel is Jackyna Hotel.
# ------------
# Retrieving Results for Index 245: Americus.
# Closest hotel is Best Western Plus Windsor Hotel.
# ------------
# Retrieving Results for Index 248: Bosaso.
# Closest hotel is Red Sea Hotel.
# ------------
# Retrieving Results for Index 253: Cassilândia.
# Closest hotel is Delirius Motel.
# ------------
# Retrieving Results for Index 255: Mahébourg.
# Closest hotel is Shandrani Beachcomber Resort & Spa.
# ------------
# Retrieving Results for Index 257: Jieshi.
# Closest hotel is Yuehai Hotel.
# ------------
# Retrieving Results for Index 265: Benguela.
# Closest hotel is Hotel Praia Morena.
# ------------
# Retrieving Results for Index 268: Kavaratti.
# Closest hotel is Hotels in Lakshadweep Islands.
# ------------
# Retrieving Results for Index 269: Corrente.
# Closest hotel is Chapadinhense Hotel.
# ------------
# Retrieving Results for Index 276: Huarmey.
# Closest hotel is Hotel Miramar.
# ------------
# Retrieving Results for Index 277: Boa Vista.
# Closest hotel is Aipana Plaza Hotel.
# ------------
# Retrieving Results for Index 278: Al Bardīyah.
# Closest hotel is بورتو بردية.
# ------------
# Retrieving Results for Index 279: Carnarvon.
# Closest hotel is Hospitality Carnarvon.
# ------------
# Retrieving Results for Index 282: Tomatlán.
# Closest hotel is El Salvial.
# ------------
# Retrieving Results for Index 286: Pangkalanbuun.
# Closest hotel is Grand Kecubung Hotel.
# ------------
# Retrieving Results for Index 288: Kieta.
# Closest hotel is Uruna Bay Retreat.
# ------------
# Retrieving Results for Index 290: Bontang.
# Closest hotel is KOPKAR Hotel Bintang Sintuk.
# ------------
# Retrieving Results for Index 292: ‘Āhuimanu.
# Closest hotel is Paradise Bay Resort.
# ------------
# Retrieving Results for Index 294: George Town.
# Closest hotel is Cititel Penang.
# ------------
# Retrieving Results for Index 296: Progreso.
# Closest hotel is Playa Linda Hotel.
# ------------
# Retrieving Results for Index 304: Ensley.
# Closest hotel is Holiday Inn Express & Suites Pensacola W I-10.
# ------------
# Retrieving Results for Index 307: Hays.
# Closest hotel is Sinya on Lone Man Creek.
# ------------
# Retrieving Results for Index 308: The Valley.
# Closest hotel is CeBlue Villas & Beach Resort.
# ------------
# Retrieving Results for Index 311: Dingle.
# Closest hotel is SEGAYA PROPERTY.
# ------------
# Retrieving Results for Index 312: Salalah.
# Closest hotel is HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel.
# ------------
# Retrieving Results for Index 313: Makakilo City.
# Closest hotel is Marriott's Ko Olina Beach Club.
# ------------
# Retrieving Results for Index 314: Ongole.
# Closest hotel is HOTEL NARAYANA PALACE.
# ------------
# Retrieving Results for Index 315: Kanniyākumāri.
# Closest hotel is Sparsa Kanyakumari.
# ------------
# Retrieving Results for Index 316: Bubaque.
# Closest hotel is Casa Dora, Bubaque.
# ------------
# Retrieving Results for Index 317: Tabora.
# Closest hotel is Barcelona Lodge.
# ------------
# Retrieving Results for Index 318: Srandakan.
# Closest hotel is Puri Brata.
# ------------
# Retrieving Results for Index 319: Ugoofaaru.
# Closest hotel is Ungoofaaru Inn.
# ------------
# Retrieving Results for Index 320: Harper.
# Closest hotel is Screensaver.
# ------------
# Retrieving Results for Index 322: Irecê.
# Closest hotel is Hotel Copa 70.
# ------------
# Retrieving Results for Index 323: Puerto Limón.
# Closest hotel is Hotel Playa Bonita.
# ------------
# Retrieving Results for Index 324: Hambantota.
# Closest hotel is Bungalow 63.
# ------------
# Retrieving Results for Index 325: Praia.
# Closest hotel is LT Aparthotel.
# ------------
# Retrieving Results for Index 329: Soc Trang.
# Closest hotel is Phu Quy Hotel.
# ------------
# Retrieving Results for Index 330: Rehoboth.
# Closest hotel is Noble Luminous Accommodation.
# ------------
# Retrieving Results for Index 334: Manzanillo.
# Closest hotel is HOSTAL "THE YELLOW HOUSE".
# ------------
# Retrieving Results for Index 342: Marzuq.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 345: Gouyave.
# Closest hotel is Rumboat Retreat.
# ------------
# Retrieving Results for Index 353: Son La.
# Closest hotel is Galaxy Grand Hotel.
# ------------
# Retrieving Results for Index 356: Itupiranga.
# Closest hotel is Hotel Panorama.
# ------------
# Retrieving Results for Index 361: Amapá.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 364: Luang Prabang.
# Closest hotel is The Apsara.
# ------------
# Retrieving Results for Index 365: Noumea.
# Closest hotel is Hôtel Le Lagon.
# ------------
# Retrieving Results for Index 366: Kaniama.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 369: Chirongui.
# Closest hotel is La Villa Mahatsara.
# ------------
# Retrieving Results for Index 370: Santa Cruz de la Sierra.
# Closest hotel is Aviador Hotel Boutique.
# ------------
# Retrieving Results for Index 371: Maragogi.
# Closest hotel is Salinas do Maragogi All Inclusive Resort.
# ------------
# Retrieving Results for Index 372: Bulungu.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 373: Muros.
# Closest hotel is Apartment Av. Castelao.
# ------------
# Retrieving Results for Index 374: Vila Velha.
# Closest hotel is Hotel Vitória Palace.
# ------------
# Retrieving Results for Index 375: Kuala Selangor.
# Closest hotel is Apps Hotel.
# ------------
# Retrieving Results for Index 378: Jāwā.
# Closest hotel is زياد الدلالشه.
# ------------
# Retrieving Results for Index 379: Martapura.
# Closest hotel is Montana Hotel Syariah.
# ------------
# Retrieving Results for Index 381: Manoel Urbano.
# Closest hotel is Baixada Beira Rio.
# ------------
# Retrieving Results for Index 382: Paphos.
# Closest hotel is Elysium Hotel.
# ------------
# Retrieving Results for Index 385: Faya.
# Closest hotel is املاك خالد الشعشوع.
# ------------
# Retrieving Results for Index 386: Camargo.
# Closest hotel is Hotel Santa Fe.
# ------------
# Retrieving Results for Index 390: Muli.
# Closest hotel is Medhufushi Island Resort.
# ------------
# Retrieving Results for Index 392: Brownsville.
# Closest hotel is Best Western Hotel Plaza Matamoros.
# ------------
# Retrieving Results for Index 400: Labuan.
# Closest hotel is Tiara Labuan Hotel.
# ------------
# Retrieving Results for Index 403: Mapastepec.
# Closest hotel is Hotel San Carlos.
# ------------
# Retrieving Results for Index 406: Atbasar.
# Closest hotel is Гостиничный Комплекс Saad.
# ------------
# Retrieving Results for Index 409: Kumluca.
# Closest hotel is TurkuazKöy.
# ------------
# Retrieving Results for Index 410: Singkang.
# Closest hotel is Kampung Seri Makmor Pagoh.
# ------------
# Retrieving Results for Index 412: Cap Malheureux.
# Closest hotel is Pereybere Hotel & Spa.
# ------------
# Retrieving Results for Index 414: Sinnamary.
# Closest hotel is ALETHEIA Appartement Sinnamary.
# ------------
# Retrieving Results for Index 415: Kalangala.
# Closest hotel is Ssese Habitat Resort.
# ------------
# Retrieving Results for Index 418: Fes.
# Closest hotel is Hotel Mounia Fès.
# ------------
# Retrieving Results for Index 422: Fare.
# Closest hotel is Maitai Lapita Village Huahine.
# ------------
# Retrieving Results for Index 426: Tiarei.
# Closest hotel is Le Rocher de Tahiti.
# ------------
# Retrieving Results for Index 427: Isangel.
# Closest hotel is Tanna Lodge.
# ------------
# Retrieving Results for Index 429: Kismayo.
# Closest hotel is Agan-Hotel.
# ------------
# Retrieving Results for Index 431: Nautla.
# Closest hotel is Casa Blanca.
# ------------
# Retrieving Results for Index 435: Marsh Harbour.
# Closest hotel is Abaco Beach Resort.
# ------------
# Retrieving Results for Index 436: Inírida.
# Closest hotel is Fuente del Guania Hotel de Lujo.
# ------------
# Retrieving Results for Index 438: Pemangkat.
# Closest hotel is Ramah Kost KITA.
# ------------
# Retrieving Results for Index 439: Santa Cruz Cabrália.
# Closest hotel is Puerto Princesa Inn.
# ------------
# Retrieving Results for Index 440: Gwadar.
# Closest hotel is Sadaf Resort.
# ------------
# Retrieving Results for Index 446: Anito.
# Closest hotel is FELIPA LAODENIO PROPERTY.
# ------------
# Retrieving Results for Index 447: Avera.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 449: Msowero.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 451: Takoradze.
# Closest hotel is Raybow International Hotel.
# ------------
# Retrieving Results for Index 456: Moerai.
# Closest hotel is Le Manotel.
# ------------
# Retrieving Results for Index 459: Puerto Parra.
# Closest hotel is Casa Hotel Villa Johana.
# ------------
# Retrieving Results for Index 463: Pitimbu.
# Closest hotel is Reserva do Abiaí.
# ------------
# Retrieving Results for Index 464: Vilhena.
# Closest hotel is Hotel Mirage.
# ------------
# Retrieving Results for Index 466: Breves.
# Closest hotel is Hotel e Restaurante Grill.
# ------------
# Retrieving Results for Index 468: Tutóia.
# Closest hotel is Pousada Guará's.
# ------------
# Retrieving Results for Index 474: Sechura.
# Closest hotel is Hospedaje Costa Bella.
# ------------
# Retrieving Results for Index 479: Andros Town.
# Closest hotel is Hanks place.
# ------------
# Retrieving Results for Index 480: Merauke.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 483: Alofi.
# Closest hotel is Taloa Heights.
# ------------
# Retrieving Results for Index 484: Pathein.
# Closest hotel is Pathein Hotel.
# ------------
# Retrieving Results for Index 485: Kahului.
# Closest hotel is Maui Seaside Hotel.
# ------------
# Retrieving Results for Index 487: St. George's.
# Closest hotel is Radisson Grenada Beach Resort.
# ------------
# Retrieving Results for Index 488: Forio.
# Closest hotel is Hotel Terme Providence.
# ------------
# Retrieving Results for Index 493: Morondava.
# Closest hotel is La Case Bambou.
# ------------
# Retrieving Results for Index 494: Sambava.
# Closest hotel is Melrose.
# ------------
# Retrieving Results for Index 496: Antofagasta.
# Closest hotel is Holiday Inn Express Antofagasta, an IHG Hotel.
# ------------
# Retrieving Results for Index 497: Rincon.
# Closest hotel is Days Inn Rincon.
# ------------
# Retrieving Results for Index 500: Crotone.
# Closest hotel is Helios Hotel.
# ------------
# Retrieving Results for Index 502: Eenhana.
# Closest hotel is Hotel Litu.
# ------------
# Retrieving Results for Index 504: Matadi.
# Closest hotel is Hotel Vivi Palace.
# ------------
# Retrieving Results for Index 506: Alcântara.
# Closest hotel is Pousada da Josefa.
# ------------
# Retrieving Results for Index 507: Tlacotepec (San Mateo).
# Closest hotel is RANCHO LA ILUSION.
# ------------
# Retrieving Results for Index 509: Mossamedes.
# Closest hotel is Hotel Chik Chik Namibe.
# ------------
# Retrieving Results for Index 510: Poum.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 514: Kathu.
# Closest hotel is Novotel Phuket Resort.
# ------------
# Retrieving Results for Index 515: Port Hedland.
# Closest hotel is The Esplanade Hotel.
# ------------
# Retrieving Results for Index 516: Karratha.
# Closest hotel is ibis Styles Karratha.
# ------------
# Retrieving Results for Index 517: Payao.
# Closest hotel is Manolita.
# ------------
# Retrieving Results for Index 519: La Unión.
# Closest hotel is Los Portales.
# ------------
# Retrieving Results for Index 523: Esim.
# Closest hotel is Axim Beach Resort And Spa.
# ------------
# Retrieving Results for Index 527: Royan.
# Closest hotel is CERISE Royan - Le Grand Hôtel de la Plage.
# ------------
# Retrieving Results for Index 528: Ambulu.
# Closest hotel is Hotel Ambulu Jember.
# ------------
# Retrieving Results for Index 529: Alcúdia.
# Closest hotel is Zafiro Tropic.
# ------------
# Retrieving Results for Index 531: Nūzvīd.
# Closest hotel is HI-TECH LODGE.
# ------------
# Retrieving Results for Index 533: Denpasar.
# Closest hotel is OYO 3156 Hotel Warta 2.
# ------------
# Retrieving Results for Index 537: Salé.
# Closest hotel is Hôtel Mercure Rabat Sheherazade.
# ------------
# Retrieving Results for Index 540: Teguise.
# Closest hotel is B&B La Casona de Nazaret.
# ------------
# Retrieving Results for Index 541: Jaru.
# Closest hotel is Hotel Paraná.
# ------------
# Retrieving Results for Index 542: Sri Aman.
# Closest hotel is Seri Simanggang Hotel.
# ------------
# Retrieving Results for Index 543: Eilat.
# Closest hotel is Club Hotel Eilat.
# ------------
# Retrieving Results for Index 548: Saint-Pierre.
# Closest hotel is Lindsey Hôtel.
# ------------
# Retrieving Results for Index 553: Clarksville.
# Closest hotel is Riverview Inn.
# ------------
# Retrieving Results for Index 560: Ratnagiri.
# Closest hotel is Hotel Landmark.
# ------------
# Retrieving Results for Index 561: Tuy Hoa.
# Closest hotel is CenDeluxe Hotel Tuy Hoa.
# ------------
# Retrieving Results for Index 563: Vao.
# Closest hotel is Hotel Kou-Bugny.
# ------------
# Retrieving Results for Index 564: Barra de Tecoanapa.
# Closest hotel is Hotel Manglares.
# ------------
# Retrieving Results for Index 566: Sola.
# Closest hotel is Leumerus Bungalows.
# ------------
# Retrieving Results for Index 567: Karak.
# Closest hotel is Cairwan Hotel.
# ------------
# Retrieving Results for Index 569: Itarema.
# Closest hotel is Sea Lounge! Bar, Club & Restaurant.
# ------------
# Retrieving Results for Index 571: Puro.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 572: Banda Aceh.
# Closest hotel is OYO 884 Rumoh PMI Hotel.
# ------------
#      Unnamed: 0            City      Lat       Lng  Max Temp  Humidity  \
# 0             0         Rikitea -23.1203 -134.9692     75.70        76
# 1             1       Phang Nga   8.4509   98.5298     80.64        92
# 2             2         Atambua  -9.1061  124.8925     73.62        90
# 6             6  Saint-Philippe -21.3585   55.7679     80.19        79
# 12           12           Vaini -21.2000 -175.2000     75.36       100
# ..          ...             ...      ...       ...       ...       ...
# 566         566            Sola -13.8833  167.5500     81.77        72
# 567         567           Karak  31.1667   35.7500     71.87        40
# 569         569         Itarema  -2.9248  -39.9167     82.85        76
# 571         571            Puro  12.4841  123.3827     81.16        82
# 572         572      Banda Aceh   5.5577   95.3222     82.42        79
#
#      Cloudiness  Wind Speed Country        Date  \
# 0            48       13.18      PF  1651331037
# 1            98        3.00      TH  1651331210
# 2            74        4.34      ID  1651331210
# 6            45       11.18      RE  1651331078
# 12          100        6.91      TO  1651331216
# ..          ...         ...     ...         ...
# 566          60        3.98      VU  1651331556
# 567           0       25.01      JO  1651331557
# 569          63       10.02      BR  1651331558
# 571          98        9.86      PH  1651331559
# 572         100        6.35      ID  1651331560
#
#                              Hotel Name
# 0                       People ThankYou
# 1                       Sunimit Mansion
# 2                        Kost Alfa Flat
# 6          Chambres d'hôte "La Trinité"
# 12                  Keleti Beach Resort
# ..                                  ...
# 566                  Leumerus Bungalows
# 567                       Cairwan Hotel
# 569  Sea Lounge! Bar, Club & Restaurant
# 571
# 572             OYO 884 Rumoh PMI Hotel
#
# [225 rows x 11 columns]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

locations = hotel_df[['Lat','Lng']]

# Create marker layer
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add layer
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='600px', margin='0 auto 0 auto', padding='1px', wi…
